# %% [markdown]
# ## Estabelecendo conexão com API do kaggle

# %%
# Install Kaggle library
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading https://files.pythonhosted.org/packages/99/33/365c0d13f07a2a54744d027fe20b60dacdfdfb33bc04746db6ad0b79340b/kaggle-1.5.10.tar.gz (59kB)
#      |████████████████████████████████| 61kB 5.2MB/s
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.10-cp36-none-any.whl size=73269 sha256=56eaddcfc73b9f863815cda8108eb5c34eb713435319717844283ae1b40f288a
#   Stored in directory: /root/.cache/pip/wheels/3a/d1/7e/6ce09b72b770149802c653a02783821629146983ee5a360f10
# Successfully built kaggle
# Installing collected packages: kaggle
#   Found existing installation: kaggle 1.5.10
#     Uninstalling kaggle-1.5.10:
#       Successfully uninstalled kaggle-1.5.10
# Successfully installed kaggle-1.5.10

# %%
# Colab library to upload files to notebook
from google.colab import files

# Upload kaggle API key file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fba6ef84-41e2-4a28-a849-2aff99c7ed5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fba6ef84-41e2-4a28-a849-2aff99c7ed5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !ls -la /root
# Out:
# total 60
# drwx------ 1 root root 4096 Feb 15 19:04 .
# drwxr-xr-x 1 root root 4096 Feb 15 19:04 ..
# -r-xr-xr-x 1 root root 1169 Jan  1  2000 .bashrc
# drwxr-xr-x 1 root root 4096 Feb 15 19:04 .cache
# drwxr-xr-x 1 root root 4096 Feb 11 16:20 .config
# drwxr-xr-x 3 root root 4096 Feb 10 14:40 .gsutil
# drwxr-xr-x 5 root root 4096 Feb 11 16:20 .ipython
# drwx------ 2 root root 4096 Feb 11 16:20 .jupyter
# drwxr-xr-x 2 root root 4096 Feb 15 19:04 .keras
# drwx------ 1 root root 4096 Feb 11 16:20 .local
# drwxr-xr-x 4 root root 4096 Feb 11 16:21 .npm
# -rw-r--r-- 1 root root  148 Aug 17  2015 .profile
# -r-xr-xr-x 1 root root  254 Jan  1  2000 .tmux.conf

# %%
# !mkdir /root/.kaggle
# !mv /content/kaggle.json /root/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# !ls -la /root/.kaggle/
# Out:
# total 16
# drwxr-xr-x 2 root root 4096 Feb 15 19:05 .
# drwx------ 1 root root 4096 Feb 15 19:05 ..
# -rw------- 1 root root   68 Feb 15 19:05 kaggle.json

# %%
# !kaggle competitions download -c cassava-leaf-disease-classification
# Out:
# Downloading cassava-leaf-disease-classification.zip to /content
# 100% 5.76G/5.76G [02:02<00:00, 33.6MB/s]
# 100% 5.76G/5.76G [02:02<00:00, 50.7MB/s]

# %% [markdown]
# ## Importando os dados da competição

# %%
# Criar diretorio para os dados no ambiente Colab e fazer unzip do pacote baixado
# !mkdir input
# !mkdir input/cassava-leaf-disease-classification

# %%
# unzip somente no diretorio contendo as imagens 'jpg' de treinamento (train_images)
! unzip cassava-leaf-disease-classification.zip train_images/*.* -d input/cassava-leaf-disease-classification

# unzip somente no diretorio contendo as imagens 'jpg' de test (test_images)
! unzip cassava-leaf-disease-classification.zip test_images/*.* -d input/cassava-leaf-disease-classification

# unzip dos demais arquivos necessários
! unzip cassava-leaf-disease-classification.zip train.csv -d input/cassava-leaf-disease-classification
! unzip cassava-leaf-disease-classification.zip sample_submission.csv -d input/cassava-leaf-disease-classification
! unzip cassava-leaf-disease-classification.zip label_num_to_disease_map.json -d input/cassava-leaf-disease-classification
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: input/cassava-leaf-disease-classification/train_images/3953530273.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3953560426.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3953648207.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3953857113.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3953901317.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3954180556.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3954239221.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3954387963.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3954399974.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3954487465.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3954910918.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3955391972.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3955442838.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3955739563.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3955931830.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3955972139.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956075690.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956077728.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956155774.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956271103.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956372146.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956407201.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956550570.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956605397.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3956778160.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3957562076.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3957612771.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3957807023.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3957819631.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/395820132.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3958304403.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/395852128.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/395853907.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3958714206.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3958986545.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3959033347.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3959151804.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3959266436.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3959470813.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3959970856.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3960301906.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396042395.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396060343.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3960669389.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3960791119.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3961078700.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3961117682.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3961136833.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396152951.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3961645455.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3962057162.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3962294427.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3962424026.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3962684748.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3962830486.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3962941156.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3962965208.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963041758.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963163426.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963194620.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963293417.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963421928.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396350327.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963572251.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963604072.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963914024.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963917355.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963919295.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3963996017.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964029612.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964066128.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964069198.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964074425.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964080612.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964124529.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964194408.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964240864.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964316261.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964372330.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964576371.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964588616.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964816822.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964842875.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964876844.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3964970132.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396499078.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3965026649.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3965161877.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3965169748.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396528848.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966039850.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966169079.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396625328.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966256467.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966311153.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966397461.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966432707.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966618744.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966914560.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3966975834.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3967002927.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3967037274.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3967050100.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3967891639.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3968048683.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3968083899.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/396829878.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3968384941.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3968735847.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3968955392.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3968956447.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3969087697.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3969288877.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3969515.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3969588604.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3969787615.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3969928849.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3970119375.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/397081522.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3971043257.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3971124978.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3971240417.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3971401456.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3971597689.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3971663926.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3971676147.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3972035105.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3972201692.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3972207361.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/397242175.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3972834452.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973042447.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973123989.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973350310.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973412468.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973452259.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973659068.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973759314.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973772550.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973846840.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3973974283.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3974310104.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3974406563.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3974455402.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3974644689.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/397477697.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3975444429.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3975487347.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3975766951.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3975873583.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3976044474.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3976294368.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3976477069.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3976765860.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3977257761.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3977307384.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3977320696.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3977561724.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3977718689.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3977934674.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3977938536.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3978175497.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3978296365.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3978345491.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3978498326.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3978633568.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/397896685.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3979130498.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3979670694.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3979826725.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3980236832.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3980286599.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3980578262.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3980819954.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/398109991.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3981217700.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3981449307.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3981645736.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3982368414.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3982901070.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3982972908.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3983156415.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3983257977.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3983529541.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3983622976.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3984046455.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3984082727.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3984375685.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3984703972.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/398530204.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3985367860.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3985416531.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3985539982.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3985545704.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3985864340.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986073933.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986159422.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986218390.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986415473.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986526512.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986617581.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986748411.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986774650.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986797492.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986821371.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3986994681.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987026948.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987029837.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987145170.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987160874.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987321075.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987329576.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987330899.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987528887.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3987800643.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3988179260.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3988520173.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3988625744.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3988748153.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3988816967.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3988908835.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3989425098.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3989450757.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3989567826.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3989761123.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/399009476.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/399128521.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3991445025.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3991703391.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3991899434.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3992156989.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3992168079.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3992333811.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3992509961.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3992628804.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3993385288.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3993406091.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3993445930.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3993544013.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3993617081.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3994140306.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3994489797.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3994624875.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3994849052.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3994869632.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995159118.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995459350.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995498206.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995539083.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995611090.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995611401.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995652879.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995855836.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995859683.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995871788.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995905691.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3995991109.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3996218398.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3996410280.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3996497470.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3996512301.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/399652571.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3997023855.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3997092474.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3997582442.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/399780928.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3997854029.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998061368.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998293147.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998419018.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998452657.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998460342.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998485682.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998876448.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998978709.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3998982675.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3999057498.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3999223206.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3999758372.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/3999919472.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4000041992.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4000198689.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4000520733.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4000584857.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/400079356.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4001352115.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4001662386.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4002244325.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4002359446.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4002980483.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4003064199.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4003333385.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4003454599.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4003743131.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4003954623.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4004133979.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4004256594.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4004395307.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4004655752.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4004943921.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4005310479.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4005501772.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4005530868.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4005695464.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/400576594.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4005806149.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4006299018.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4006518224.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4006579451.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/400659016.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4006771974.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/400686072.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4007062391.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4007185339.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4007199956.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4007234267.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4007496530.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4007863717.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/400794559.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4008326221.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4008495271.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4009113191.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4009310147.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4009415549.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4009427061.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4009888434.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4010033110.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4010091989.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4010133596.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/401014506.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/401103417.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4011347600.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4011584654.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4011808410.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4011855023.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4012035359.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4012105605.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4012298941.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4012991652.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4013151880.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4013206965.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4013482004.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4013610919.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4013834415.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4013991367.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4014439076.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4014877464.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4014881433.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4014913503.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4015277516.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/401560785.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4016073096.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4016154109.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4016279583.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4016400274.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4016407107.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4016547157.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4016802646.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017187341.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017354587.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017387228.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017647533.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017689394.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017822607.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017896312.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/401790013.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4017977717.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4018169789.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/401824702.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/401825012.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4018250398.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4018307313.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4018364725.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4018367133.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4018898833.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4018949072.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4019060671.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4019065947.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4019067935.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4019214613.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4019472268.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4019771530.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4020055407.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4020073258.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4020138210.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4020462779.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4020967686.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4021015970.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4021120982.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4021769307.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4022000067.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402211676.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4022128079.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4022798796.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402280669.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4022871563.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4022972553.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4022980210.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4024341056.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4024391744.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4024425381.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4024428406.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4024436293.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4024636592.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4025247063.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4025505972.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4025590571.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4025854027.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4025993930.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4026064019.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402606580.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4026684435.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4026736343.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4026910494.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4027254563.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4027944552.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402862496.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402874662.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402875912.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4028806922.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4028883745.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4028966918.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4029027750.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402961309.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/402962978.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4029728754.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4029880572.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4029905096.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4030129065.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4030345152.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4030356791.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4030410880.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403051866.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4030982383.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031122706.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031188863.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031297900.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031321038.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031374252.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031511007.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031523832.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031627524.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031789905.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031880127.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4031957327.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4032292698.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4032326580.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403241496.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4032774501.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4032903735.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403293009.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4032940326.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4033298149.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403345253.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4033546541.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403372857.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4033870667.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034095153.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403422220.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034332345.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403440184.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034495674.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034498053.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034547314.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034553253.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403458333.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034653549.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4034666533.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403476410.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4035576240.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4035811730.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4035835394.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4036100881.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4036105950.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4036237704.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4036527823.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4036777489.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403680473.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037044151.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037316351.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037341116.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403735844.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037393509.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037509269.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037648479.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037735151.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037829966.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4037870925.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4038168935.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4038284250.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4038344014.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4038568741.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4038643368.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403910552.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4039408618.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4039538172.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/403963359.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4039669211.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4040102956.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4040156841.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4040452479.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/404066691.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4040861068.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/404115232.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4041427827.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4042037111.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4042084056.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4042496889.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4042964772.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4043076131.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4043153792.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4043211245.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4043869250.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4044063310.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4044222946.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4044329664.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4044444164.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4044550421.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4044829046.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4044997961.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4045015795.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4045136417.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4045142021.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4045262215.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4045566880.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046068592.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046154865.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046217352.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046239145.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046290790.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046649903.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046661202.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4046910331.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4047167362.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4047585545.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4047998740.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4048156987.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4048354655.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/404837485.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4048377608.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4048486399.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4048519217.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/404853146.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4048650706.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4048732920.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/404883957.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4049425598.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4049438636.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4049710650.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4049743612.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4049843068.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4050218395.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4050620489.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4050718274.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4050750401.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4050904412.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4051003869.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4051205328.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4051216052.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4051367500.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4052176327.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4052185416.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4052298208.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/4052486714.jpg
# ...
#   inflating: input/cassava-leaf-disease-classification/train_images/96246425.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/962558857.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/963168720.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/963176335.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/963450221.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/963790461.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/964030938.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/964359867.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/964482896.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/964570288.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/964655123.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/965026603.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/965133347.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/965889493.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/965919968.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/966050678.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/966306135.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/966432144.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/966652545.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/966788042.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/967123833.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/967319500.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/967603965.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/967831491.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/967883712.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/968449352.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/968472833.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/968790449.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/968853775.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/968865165.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/969069572.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/96912752.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/969194504.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/969211018.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/969351419.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/969719974.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/969749670.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/969938724.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/970041120.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/970540696.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/970669415.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/970899436.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/970946808.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/971188113.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/971500459.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/971639298.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/971713914.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/972419188.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/972622677.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/972649867.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/972793378.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/972840038.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/972873188.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/97287651.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/972959733.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/973300702.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/973746900.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/97383533.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/974073314.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/974489379.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/974614447.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/975110881.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/975158492.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/975311959.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/975534940.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/975560905.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976098356.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976138379.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976558597.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976680630.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976801924.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976902576.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976955239.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/976976000.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/977106252.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/977380491.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/977617704.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/977709534.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/977735708.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/978029996.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/978111352.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/978618490.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/978877878.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/979088794.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/979089486.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/979574790.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/979671168.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/979717744.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/979858694.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/979927449.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/980174544.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/980401006.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/980448273.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/980682914.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/980911264.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/981211210.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/981248959.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/98151706.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/981946821.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/981961513.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982230894.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982241079.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982255022.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982343142.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982426232.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982556736.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982733151.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982829407.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/982968211.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/983014273.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/983360921.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/983368345.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/984082173.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/984192870.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/984417293.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/984672636.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/984892057.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/985972952.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986134312.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986273020.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986387276.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986788190.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986854149.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986888785.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986965803.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/986999751.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/987080644.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/987098553.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/987159645.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/987636835.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/988174802.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/988306549.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/988318054.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/989030666.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/989119004.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/989164337.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/989239917.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/990558315.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/99056821.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/990768027.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/990890343.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/991522911.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/991676292.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/991916399.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/99202708.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/992163916.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/992224132.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/992352996.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/992748624.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/992964459.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/993130539.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/993366541.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/993844551.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/99391680.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/993984792.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/994252979.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/994445094.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/994621972.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/994727955.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/995075067.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/995123333.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/995155483.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/995221528.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/99645916.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/996534381.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/996539252.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/996762577.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/996927503.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/996947690.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/996957803.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997161074.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997179968.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997289539.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997485103.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997651546.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997857988.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997910101.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/997973414.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/998910982.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/999068805.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/999329392.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/999474432.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/999616605.jpg
#   inflating: input/cassava-leaf-disease-classification/train_images/999998473.jpg
# Archive:  cassava-leaf-disease-classification.zip
#   inflating: input/cassava-leaf-disease-classification/test_images/2216849948.jpg
# Archive:  cassava-leaf-disease-classification.zip
#   inflating: input/cassava-leaf-disease-classification/train.csv
# Archive:  cassava-leaf-disease-classification.zip
#   inflating: input/cassava-leaf-disease-classification/sample_submission.csv
# Archive:  cassava-leaf-disease-classification.zip
#   inflating: input/cassava-leaf-disease-classification/label_num_to_disease_map.json

# %% [markdown]
# ## Set up environment

# %%
import re, os, sys
import json
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from sklearn.model_selection import train_test_split
import cv2
from collections import Counter

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

from tqdm.notebook import tqdm
from PIL import Image
import datetime
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.metrics import accuracy_score

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.4.1

# %% [markdown]
# ## EDA

# %%
RANDOM_STATE = 2021

WORK_DIR = '../content/input/cassava-leaf-disease-classification'
os.listdir(WORK_DIR)
# Out:
# ['train.csv',
#  'train_images',
#  'label_num_to_disease_map.json',
#  'test_images',
#  'sample_submission.csv']

# %%
print('Train images: %d' %len(os.listdir(
    os.path.join(WORK_DIR, "train_images"))))
# Out:
# Train images: 21397

# %%
with open(os.path.join(WORK_DIR, "label_num_to_disease_map.json")) as file:
    print(json.dumps(json.loads(file.read()), indent=4))
# Out:
# {
#     "0": "Cassava Bacterial Blight (CBB)",
#     "1": "Cassava Brown Streak Disease (CBSD)",
#     "2": "Cassava Green Mottle (CGM)",
#     "3": "Cassava Mosaic Disease (CMD)",
#     "4": "Healthy"
# }

# %%
# Carregar arquivo train.csv
train_labels = pd.read_csv(os.path.join(WORK_DIR, "train.csv"))
train_labels
# Out:
#              image_id  label
# 0      1000015157.jpg      0
# 1      1000201771.jpg      3
# 2       100042118.jpg      1
# 3      1000723321.jpg      1
# 4      1000812911.jpg      3
# ...               ...    ...
# 21392   999068805.jpg      3
# 21393   999329392.jpg      3
# 21394   999474432.jpg      1
# 21395   999616605.jpg      4
# 21396   999998473.jpg      4
#
# [21397 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))

sns.set_style('whitegrid')

ax=sns.countplot(data=train_labels, x='label')


#  '0': 'Cassava Bacterial Blight (CBB)
#  '1': 'Cassava Brown Streak Disease (CBSD)
#  '2': 'Cassava Green Mottle (CGM)
#  '3': 'Cassava Mosaic Disease (CMD)
#  '4': 'Healthy

# %%
CLASS_WEIGHT = dict(train_labels.label.value_counts()/train_labels.shape[0])
CLASS_WEIGHT
# Out:
# {0: 0.05080151423096696,
#  1: 0.10230406131700706,
#  2: 0.11151095948030097,
#  3: 0.6149460204701593,
#  4: 0.12043744450156564}

# %% [markdown]
# ## Dividir o conjunto em treino/teste (hold-out)

# %%
x = train_labels.image_id
y = train_labels.label

# %%
# usar o train_test_split para separar um conjunto de dados para teste (hold-out) -> fazer a predição
# proporções 95/5
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = RANDOM_STATE, test_size=0.05)

# %%
# criando um novo df só com (x_train, y_train) para inserir no IMAGEDATAGENERATOR

train_val = {'image_id':x_train,
             'label':y_train}
df_train_val = pd.DataFrame(train_val)
df_train_val.reset_index(drop=True, inplace=True)

df_train_val
# Out:
#              image_id  label
# 0      3567421807.jpg      4
# 1      4255258797.jpg      3
# 2        87295869.jpg      2
# 3      1696401530.jpg      3
# 4       484286450.jpg      3
# ...               ...    ...
# 20322  3944665057.jpg      3
# 20323   791667524.jpg      2
# 20324  1465491965.jpg      3
# 20325  4160459669.jpg      3
# 20326  2109494038.jpg      3
#
# [20327 rows x 2 columns]

# %%
# criando um novo df só com (x_test, y_test) para avaliar o modelo com TTA

test_set = {'image_id':x_test,
             'label':y_test}
df_test = pd.DataFrame(test_set)
df_test.reset_index(drop=True, inplace=True)

df_test
# Out:
#             image_id  label
# 0     1962633596.jpg      1
# 1     2620830475.jpg      1
# 2     1284779898.jpg      4
# 3     2278366099.jpg      3
# 4     3709090088.jpg      4
# ...              ...    ...
# 1065   455136283.jpg      3
# 1066  2089510627.jpg      3
# 1067  1983411262.jpg      4
# 1068  2454252015.jpg      4
# 1069  1870471457.jpg      3
#
# [1070 rows x 2 columns]

# %% [markdown]
# ## # Set up variables
# We'll set up some of our variables for our notebook here.

# %%
# target size and number of epochs can be tuned to your needs for obtaining better accuracy

BATCH_SIZE = 16
STEPS_PER_EPOCH = len(df_train_val)*0.8 // BATCH_SIZE
VALIDATION_STEPS = len(df_train_val)*0.2 // BATCH_SIZE
EPOCHS = 15
TARGET_SIZE = 512

CLASSES = ['0', '1', '2', '3', '4']
NUM_CLASSES = len(CLASSES)

# %% [markdown]
# ### IMAGEDATAGENERATOR

# %%
df_train_val.label = df_train_val.label.astype('str')

train_datagen = ImageDataGenerator(validation_split = 0.2,
                                     preprocessing_function = None,
                                     rotation_range = 45,
                                     zoom_range = 0.2,
                                     horizontal_flip = True,
                                     #vertical_flip = True,
                                     fill_mode = 'nearest',
                                     shear_range = 0.1,
                                     height_shift_range = 0.1,
                                     width_shift_range = 0.1)

train_generator = train_datagen.flow_from_dataframe(df_train_val,
                         directory = os.path.join(WORK_DIR, "train_images"),
                         subset = "training",
                         x_col = "image_id",
                         y_col = "label",
                         target_size = (TARGET_SIZE, TARGET_SIZE),
                         batch_size = BATCH_SIZE,
                         class_mode = "sparse")


validation_datagen = ImageDataGenerator(validation_split = 0.2)

validation_generator = validation_datagen.flow_from_dataframe(df_train_val,
                         directory = os.path.join(WORK_DIR, "train_images"),
                         subset = "validation",
                         x_col = "image_id",
                         y_col = "label",
                         target_size = (TARGET_SIZE, TARGET_SIZE),
                         batch_size = BATCH_SIZE,
                         class_mode = "sparse")
# Out:
# Found 16262 validated image filenames belonging to 5 classes.
# Found 4065 validated image filenames belonging to 5 classes.

# %% [markdown]
# ## Model

# %%
import tensorflow.keras.applications as all_nn
dir(all_nn)
# Out:
# ['DenseNet121',
#  'DenseNet169',
#  'DenseNet201',
#  'EfficientNetB0',
#  'EfficientNetB1',
#  'EfficientNetB2',
#  'EfficientNetB3',
#  'EfficientNetB4',
#  'EfficientNetB5',
#  'EfficientNetB6',
#  'EfficientNetB7',
#  'InceptionResNetV2',
#  'InceptionV3',
#  'MobileNet',
#  'MobileNetV2',
#  'MobileNetV3Large',
#  'MobileNetV3Small',
#  'NASNetLarge',
#  'NASNetMobile',
#  'ResNet101',
#  'ResNet101V2',
#  'ResNet152',
#  'ResNet152V2',
#  'ResNet50',
#  'ResNet50V2',
#  'VGG16',
#  'VGG19',
#  'Xception',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sys',
#  'densenet',
#  'efficientnet',
#  'imagenet_utils',
#  'inception_resnet_v2',
#  'inception_v3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3',
#  'nasnet',
#  'resnet',
#  'resnet50',
#  'resnet_v2',
#  'vgg16',
#  'vgg19',
#  'xception']

# %%
# EfficientNetB3

def build_efnB0():
    conv_base = all_nn.EfficientNetB3(include_top = False,
                                      weights = 'imagenet',
                                      input_shape = (TARGET_SIZE, TARGET_SIZE, 3))
    # Freeze the pretrained weights
    #conv_base.trainable = False
    
    
    # Rebuild top with fine-tuning
    model = conv_base.output
    model = layers.GlobalAveragePooling2D()(model)
    model = layers.Dense(NUM_CLASSES, activation = "softmax")(model)
    model = models.Model(conv_base.input, model)
    
    #Compile
    model.compile(optimizer = Adam(lr = 0.001),
                  loss = "sparse_categorical_crossentropy",
                  metrics = ["acc"])
    return model

# %%
#model_0 = build_ResNet50()

# %%
#model_0.summary()

# %%
#print('Our RestNet50 CNN has %d layers' %len(model1.layers))

# %%
efnB0 = build_efnB0()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 0s 0us/step

# %%
efnB0.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 512, 512, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 512, 512, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 513, 513, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 256, 256, 40) 1080        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 256, 256, 40) 160         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 256, 256, 40) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 256, 256, 40) 360         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 256, 256, 40) 160         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 256, 256, 40) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 40)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 40)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 10)     410         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 40)     440         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 256, 256, 40) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 256, 256, 24) 960         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 256, 256, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 256, 256, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 256, 256, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 256, 256, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 256, 256, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 256, 256, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 256, 256, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 256, 256, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 256, 256, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 256, 256, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 256, 256, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 256, 256, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 257, 257, 144 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 128, 128, 144 1296        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 128, 128, 144 576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 128, 128, 144 0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 128, 128, 144 0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 128, 128, 32) 4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 128, 128, 32) 128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 128, 128, 192 768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 128, 128, 192 0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 128, 128, 192 768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 128, 128, 192 0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 128, 128, 192 0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 128, 128, 32) 128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 128, 128, 32) 0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 128, 128, 32) 0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 128, 128, 192 768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 128, 128, 192 0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 128, 128, 192 1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 128, 128, 192 768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 128, 128, 192 0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 128, 128, 192 0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 128, 128, 32) 6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 128, 128, 32) 128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 128, 128, 32) 0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 128, 128, 32) 0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 128, 128, 192 6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 128, 128, 192 768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 128, 128, 192 0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 131, 131, 192 0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 64, 64, 192)  4800        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 64, 64, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 64, 64, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 64, 64, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 64, 64, 48)   9216        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 64, 64, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 64, 64, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 64, 64, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 64, 64, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 64, 64, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 64, 64, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 64, 64, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 64, 64, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 64, 64, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 64, 64, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 64, 64, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 64, 64, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 64, 64, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 64, 64, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 64, 64, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 64, 64, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 64, 64, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 64, 64, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 64, 64, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 64, 64, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 64, 64, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 64, 64, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 64, 64, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 64, 64, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 64, 64, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 64, 64, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 65, 65, 288)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 32, 32, 288)  2592        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 32, 32, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 32, 32, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 32, 32, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 32, 32, 96)   27648       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 32, 32, 96)   384         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 32, 32, 576)  55296       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 32, 32, 576)  2304        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 32, 32, 576)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 32, 32, 576)  5184        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 32, 32, 576)  2304        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 32, 32, 576)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 576)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 32, 32, 576)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 32, 32, 96)   55296       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 32, 32, 96)   384         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 32, 32, 96)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 32, 32, 96)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 32, 32, 576)  55296       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 32, 32, 576)  2304        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 32, 32, 576)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 32, 32, 576)  5184        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 32, 32, 576)  2304        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 32, 32, 576)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 576)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 32, 32, 576)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 32, 32, 96)   55296       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 32, 32, 96)   384         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 32, 32, 96)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 32, 32, 96)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 32, 32, 576)  55296       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 32, 32, 576)  2304        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 32, 32, 576)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 32, 32, 576)  5184        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 32, 32, 576)  2304        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 32, 32, 576)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 576)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 32, 32, 576)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 32, 32, 96)   55296       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 32, 32, 96)   384         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 32, 32, 96)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 32, 32, 96)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, 32, 32, 576)  55296       block4d_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, 32, 32, 576)  2304        block4e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, 32, 32, 576)  0           block4e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, 32, 32, 576)  5184        block4e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, 32, 32, 576)  2304        block4e_dwconv[0][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, 32, 32, 576)  0           block4e_bn[0][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 576)          0           block4e_activation[0][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, 32, 32, 576)  0           block4e_activation[0][0]
#                                                                  block4e_se_expand[0][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, 32, 32, 96)   55296       block4e_se_excite[0][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, 32, 32, 96)   384         block4e_project_conv[0][0]
# __________________________________________________________________________________________________
# block4e_drop (Dropout)          (None, 32, 32, 96)   0           block4e_project_bn[0][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, 32, 32, 96)   0           block4e_drop[0][0]
#                                                                  block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 32, 32, 576)  55296       block4e_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 32, 32, 576)  2304        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 32, 32, 576)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 32, 32, 576)  14400       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 32, 32, 576)  2304        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 32, 32, 576)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 576)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 576)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 32, 32, 576)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 32, 32, 136)  78336       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 32, 32, 136)  544         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 32, 32, 816)  110976      block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 32, 32, 816)  3264        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 32, 32, 816)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 32, 32, 816)  20400       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 32, 32, 816)  3264        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 32, 32, 816)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 816)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 816)    28560       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 32, 32, 816)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 32, 32, 136)  110976      block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 32, 32, 136)  544         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 32, 32, 136)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 32, 32, 136)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 32, 32, 816)  110976      block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 32, 32, 816)  3264        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 32, 32, 816)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 32, 32, 816)  20400       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 32, 32, 816)  3264        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 32, 32, 816)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 816)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6d_dwconv (DepthwiseConv2D (None, 16, 16, 1392) 34800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 16, 16, 1392) 5568        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 16, 16, 1392) 0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1392)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 16, 16, 1392) 0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 16, 16, 232)  322944      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 16, 16, 232)  928         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 16, 16, 232)  0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 16, 16, 232)  0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 16, 16, 1392) 322944      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 16, 16, 1392) 5568        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 16, 16, 1392) 0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 16, 16, 1392) 34800       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 16, 16, 1392) 5568        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 16, 16, 1392) 0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1392)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 16, 16, 1392) 0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 16, 16, 232)  322944      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 16, 16, 232)  928         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 16, 16, 232)  0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 16, 16, 232)  0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block6f_expand_conv (Conv2D)    (None, 16, 16, 1392) 322944      block6e_add[0][0]
# __________________________________________________________________________________________________
# block6f_expand_bn (BatchNormali (None, 16, 16, 1392) 5568        block6f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6f_expand_activation (Acti (None, 16, 16, 1392) 0           block6f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6f_dwconv (DepthwiseConv2D (None, 16, 16, 1392) 34800       block6f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6f_bn (BatchNormalization) (None, 16, 16, 1392) 5568        block6f_dwconv[0][0]
# __________________________________________________________________________________________________
# block6f_activation (Activation) (None, 16, 16, 1392) 0           block6f_bn[0][0]
# __________________________________________________________________________________________________
# block6f_se_squeeze (GlobalAvera (None, 1392)         0           block6f_activation[0][0]
# __________________________________________________________________________________________________
# block6f_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6f_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6f_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6f_se_excite (Multiply)    (None, 16, 16, 1392) 0           block6f_activation[0][0]
#                                                                  block6f_se_expand[0][0]
# __________________________________________________________________________________________________
# block6f_project_conv (Conv2D)   (None, 16, 16, 232)  322944      block6f_se_excite[0][0]
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, 16, 16, 232)  928         block6f_project_conv[0][0]
# __________________________________________________________________________________________________
# block6f_drop (Dropout)          (None, 16, 16, 232)  0           block6f_project_bn[0][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, 16, 16, 232)  0           block6f_drop[0][0]
#                                                                  block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 16, 16, 1392) 322944      block6f_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 16, 16, 1392) 5568        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 16, 16, 1392) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 16, 16, 1392) 12528       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 16, 16, 1392) 5568        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 16, 16, 1392) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1392)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 16, 16, 1392) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 16, 16, 384)  534528      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 16, 16, 384)  1536        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 16, 16, 2304) 884736      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 16, 16, 2304) 9216        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 16, 16, 2304) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 16, 16, 2304) 20736       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 16, 16, 2304) 9216        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 16, 16, 2304) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2304)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 16, 16, 2304) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 16, 16, 384)  884736      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 16, 16, 384)  1536        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 16, 16, 384)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 16, 16, 384)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 16, 16, 1536) 589824      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 16, 16, 1536) 6144        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 16, 16, 1536) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1536)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            7685        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 10,791,220
# Trainable params: 10,703,917
# Non-trainable params: 87,303
# __________________________________________________________________________________________________

# %%
print('Our EfficientNetB3 CNN has %d layers' %len(efnB0.layers))
# Out:
# Our EfficientNetB3 CNN has 386 layers

# %%
model_save = ModelCheckpoint('./EffNetB3_512_8_best_weights.h5', 
                             save_best_only = True, 
                             save_weights_only = True,
                             monitor = 'val_loss', 
                             mode = 'min', verbose = 1)
early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0.001, 
                           patience = 5, mode = 'min', verbose = 1,
                           restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.3, 
                              patience = 2, min_delta = 0.001, 
                              mode = 'min', verbose = 1)

# %%
# Vefificar se GPU esta ativa

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
history = efnB0.fit(
    train_generator,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs = EPOCHS,
    validation_data = validation_generator,
    validation_steps = VALIDATION_STEPS,
    class_weight=CLASS_WEIGHT,
    callbacks = [model_save, early_stop, reduce_lr]
)
# Out:
# Epoch 1/15
# 2032/2032 [==============================] - 1702s 828ms/step - loss: 0.1286 - acc: 0.6840 - val_loss: 0.6096 - val_acc: 0.8243
#
# Epoch 00001: val_loss improved from inf to 0.60964, saving model to ./EffNetB3_512_8_best_weights.h5
# Epoch 2/15
# 2032/2032 [==============================] - 1682s 828ms/step - loss: 0.0889 - acc: 0.7619 - val_loss: 0.7683 - val_acc: 0.7714
#
# Epoch 00002: val_loss did not improve from 0.60964
# Epoch 3/15
# 2032/2032 [==============================] - 1682s 828ms/step - loss: 0.0797 - acc: 0.7887 - val_loss: 0.5322 - val_acc: 0.8246
#
# Epoch 00003: val_loss improved from 0.60964 to 0.53222, saving model to ./EffNetB3_512_8_best_weights.h5
# Epoch 4/15
# 2032/2032 [==============================] - 1681s 827ms/step - loss: 0.0766 - acc: 0.7903 - val_loss: 0.5644 - val_acc: 0.8329
#
# Epoch 00004: val_loss did not improve from 0.53222
# Epoch 5/15
# 2032/2032 [==============================] - 1680s 826ms/step - loss: 0.0719 - acc: 0.8086 - val_loss: 0.7459 - val_acc: 0.7244
#
# Epoch 00005: val_loss did not improve from 0.53222
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 6/15
# 2032/2032 [==============================] - 1681s 827ms/step - loss: 0.0618 - acc: 0.8377 - val_loss: 0.4417 - val_acc: 0.8666
#
# Epoch 00006: val_loss improved from 0.53222 to 0.44174, saving model to ./EffNetB3_512_8_best_weights.h5
# Epoch 7/15
# 2032/2032 [==============================] - 1680s 827ms/step - loss: 0.0548 - acc: 0.8611 - val_loss: 0.4071 - val_acc: 0.8728
#
# Epoch 00007: val_loss improved from 0.44174 to 0.40714, saving model to ./EffNetB3_512_8_best_weights.h5
# Epoch 8/15
# 2032/2032 [==============================] - 1679s 826ms/step - loss: 0.0525 - acc: 0.8590 - val_loss: 0.4615 - val_acc: 0.8563
#
# Epoch 00008: val_loss did not improve from 0.40714
# Epoch 9/15
# 2032/2032 [==============================] - 1681s 827ms/step - loss: 0.0514 - acc: 0.8602 - val_loss: 0.4550 - val_acc: 0.8561
#
# Epoch 00009: val_loss did not improve from 0.40714
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 10/15
#  122/2032 [>.............................] - ETA: 25:12 - loss: 0.0466 - acc: 0.8486

# %% [markdown]
# ## Evaluating our model

# %%
# print out variables available to us
print(history.history.keys())

# %% [markdown]
# ### Learning curves - Graphical evaluation

# %%
# create learning curves to evaluate model performance
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['acc', 'val_acc']].plot();

# %% [markdown]
# ## Saving the model

# %%
efnB0.save('model_efnB3.h5')

# %% [markdown]
# ## Making predictions
#
# > ### Preprocess test data

# %%
test_image = []
for i in tqdm(range(x_test.shape[0])):
    img = image.load_img(WORK_DIR+'/train_images'+'/'+df_test['image_id'][i],target_size=(TARGET_SIZE,TARGET_SIZE,3))
    img = image.img_to_array(img)
    test_image.append(img)
X_test = np.array(test_image)

# %%
X_test.shape

# %%
y_test = np.array(y_test)
y_test

# %% [markdown]
# ### Define the test Image Generator

# %%
test_datagen = ImageDataGenerator(preprocessing_function = None,
                                  rotation_range = 45,
                                  zoom_range = 0.2,
                                  horizontal_flip = True,
                                  #vertical_flip = True,
                                  fill_mode = 'nearest',
                                  shear_range = 0.1,
                                  height_shift_range = 0.1,
                                  width_shift_range = 0.1)

test_generator = test_datagen.flow(X_test,
                                   batch_size=BATCH_SIZE,
                                   shuffle=False)

# %% [markdown]
# ### TTA

# %%
tta_steps = 4

# %%
predictions = []

for i in tqdm(range(tta_steps)):
    preds = efnB0.predict(test_generator)
    predictions.append(preds)

# %%
final_preds = np.mean(predictions, axis=0)

print(final_preds)
# final_preds determina a classe com maior probabilidade na média

# %% [markdown]
# ## Evaluation

# %%
print(f'Baseline accuracy: {efnB0.evaluate(X_test, y_test)[1]}')

# %%
print(f'Accuracy with TTA: {np.mean(np.equal(y_test, np.argmax(final_preds, axis=-1)))}')
